# %%
import os
from pathlib import Path

# Store in project directory
try:
    # This works when running as a script file
    project_root = Path(__file__).parent
except NameError:
    # This works in interactive environments
    project_root = Path.cwd()

storage_dir = project_root / "crewal_storage"

os.environ["CREWAL_STORAGE_DIR"] = str(storage_dir)

# Now all storage will be in your project directory

# %%
import nest_asyncio


nest_asyncio.apply()

# %%
from crewai import Crew, Agent, Task, Process

# Define a simple agent (assuming a default LLM agent)
assistant = Agent(role="Personal Assistant",
                  goal="""You are a personal assistant that can
                          help the user with their tasks.""",
                  backstory="""You are a personal assistant that
                               can help the user with their tasks.""",
                  verbose=True)

task = Task(description="Handle this task: {user_task}",
            expected_output="A clear and concise answer to the question.",
            agent=assistant)

# Create a crew with memory enabled
crew = Crew(
    agents=[assistant], 
    tasks=[task], 
    process=Process.sequential,
    verbose=True
)

# %%
user_input = """My favorite color is #46778F and
                my favorite Agent framework is CrewAI."""

result = crew.kickoff(inputs={"user_task": user_input})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 9073d6eb-a091-4ae4-b0a0-53801c7ae453                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Task: Handle this task: My favorite color is #46778F and                                                       │
# │                  my favorite Agent framework is CrewAI.                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is #46778F, and your favorite Agent framework is CrewAI.                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 76c519da-c531-40a5-a702-3e16c24c1df5                                                                     │
# │  Agent: Personal Assistant                                                                                      │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 9073d6eb-a091-4ae4-b0a0-53801c7ae453                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: Your favorite color is #46778F, and your favorite Agent framework is CrewAI.                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
user_input = "What is my favorite color?"

result = crew.kickoff(inputs={"user_task": user_input})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 9073d6eb-a091-4ae4-b0a0-53801c7ae453                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Task: Handle this task: What is my favorite color?                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is not explicitly provided in our conversation. Please let me know what your favorite      │
# │  color is, and I can assist you further with that information!                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 76c519da-c531-40a5-a702-3e16c24c1df5                                                                     │
# │  Agent: Personal Assistant                                                                                      │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 9073d6eb-a091-4ae4-b0a0-53801c7ae453                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: Your favorite color is not explicitly provided in our conversation. Please let me know what      │
# │  your favorite color is, and I can assist you further with that information!                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ### Short Term Memory

# %%
from crewai import Crew, Agent, Task, Process

# Define a simple agent (assuming a default LLM agent)
assistant = Agent(role="Personal Assistant",
                  goal="""You are a personal assistant that can
                          help the user with their tasks.""",
                  backstory="""You are a personal assistant that
                               can help the user with their tasks.""",
                  verbose=True)

task = Task(description="Handle this task: {user_task}",
            expected_output="A clear and concise answer to the question.",
            agent=assistant)

# Create a crew with memory enabled
crew = Crew(
    agents=[assistant], 
    tasks=[task], 
    process=Process.sequential,
    memory=True,
    verbose=True
)

# %%
# !pip show crewai
# Out:
# Name: crewai
# Version: 0.157.0
# Summary: Cutting-edge framework for orchestrating role-playing, autonomous AI agents. By fostering collaborative intelligence, CrewAI empowers agents to work together seamlessly, tackling complex tasks.
# Home-page: https://crewai.com
# Author:
# Author-email: Joao Moura <joao@crewai.com>
# License:
# Location: /Users/arunkumar/anaconda3/envs/py312/lib/python3.12/site-packages
# Requires: appdirs, blinker, chromadb, click, instructor, json-repair, json5, jsonref, litellm, onnxruntime, openai, openpyxl, opentelemetry-api, opentelemetry-exporter-otlp-proto-http, opentelemetry-sdk, pdfplumber, portalocker, pydantic, pyjwt, python-dotenv, pyvis, regex, tokenizers, tomli, tomli-w, uv
# Required-by:

# %%
user_input = """My favorite color is #46778F and
                my favorite Agent framework is CrewAI."""

result = crew.kickoff(inputs={"user_task": user_input})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 72afb7f9-013f-4a41-a7c0-8dbf5eda584a                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭────────────────────────────────────────────── 🧠 Retrieved Memory ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Historical Data:                                                                                               │
# │  - Ensure the task description asks for specific information clearly.                                           │
# │  - Encourage direct responses without unnecessary introductory phrases.                                         │
# │  - Clarify that the final answer should be succinct and directly related to the question.                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────── Retrieval Time: 2923.25ms ───────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Task: Handle this task: My favorite color is #46778F and                                                       │
# │                  my favorite Agent framework is CrewAI.                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is #46778F and your favorite Agent framework is CrewAI.                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 9d4e3f65-4ff7-4fa0-9a52-556920ffad94                                                                     │
# │  Agent: Personal Assistant                                                                                      │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 72afb7f9-013f-4a41-a7c0-8dbf5eda584a                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: Your favorite color is #46778F and your favorite Agent framework is CrewAI.                      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
user_input = "What is my favorite color?"

result = crew.kickoff(inputs={"user_task": user_input})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: d0858f3c-4b37-4faa-bec2-7d22ad76864c                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Task: Handle this task: What is my favorite color?                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Personal Assistant                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  I currently do not have information about your favorite color. Please provide me with your favorite color so   │
# │  that I can assist you further!                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: ac939997-f198-4d93-a39a-e2c5d50ab757                                                                     │
# │  Agent: Personal Assistant                                                                                      │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: d0858f3c-4b37-4faa-bec2-7d22ad76864c                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: I currently do not have information about your favorite color. Please provide me with your       │
# │  favorite color so that I can assist you further!                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
crew._short_term_memory
# Out:
# ShortTermMemory(embedder_config=None, crew=None, storage=<crewai.memory.storage.rag_storage.RAGStorage object at 0x15e6a60c0>)

# %%
user_input = "What is my favorite color?"

crew._short_term_memory.storage.search(user_input)
# Out:
# [{'id': '1aebac0a-57b9-451d-8c80-eb0e9d692944',
#   'metadata': {'observation': 'Handle this task: My favorite color is #46778F and\n                my favorite Agent framework is CrewAI.',
#    'agent': 'Personal Assistant'},
#   'context': 'I now can give a great answer  \nFinal Answer: Your favorite color is #46778F and your favorite Agent framework is CrewAI.',
#   'score': 0.9171472787857056}]

# %%
crew._long_term_memory.search(user_input)

# %%
user_input = "What is my favorite color?"

crew._entity_memory.search(user_input)
# Out:
# [{'id': '9e0d6b78-f8ca-4da5-8b28-e7ad93d6934b',
#   'metadata': {'relationships': ''},
#   'context': "favorite color(string): The user's preferred color represented in hexadecimal format.",
#   'score': 0.9795557260513306},
#  {'id': '9a425802-f3dc-456f-9c55-f137dcd4a4cf',
#   'metadata': {'relationships': ''},
#   'context': "favorite Agent framework(string): The user's preferred agent framework, specified by name.",
#   'score': 1.6307812929153442}]

# %% [markdown]
# ### More on Memory

# %%
from crewai import Crew, Agent, Task, Process
from crewai.memory import ShortTermMemory
from crewai.memory.storage.rag_storage import RAGStorage

shared_db = "./short_term_memory.db"

storage = RAGStorage(path=shared_db, type="short_term")

short_term_memory = ShortTermMemory(storage=storage)

# %%
agent = Agent(role="A Personal Assistant",
              goal="""You are a personal assistant that can
                      help the user with their tasks.""",
              backstory="""You are a personal assistant that
                           can help the user with their tasks.""",
              verbose=True)

task = Task(description="Handle this task: {user_task}",
            expected_output="A clear and concise answer to the question.",
            agent=agent)


crew = Crew(
    agents=[agent], 
    tasks=[task], 
    process=Process.sequential,
    memory=True,
    short_term_memory=short_term_memory
)
crew.kickoff(inputs={"user_task": "My favorite color is #46778F."})
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: A Personal Assistant                                                                                    │
# │                                                                                                                 │
# │  Task: Handle this task: My favorite color is #46778F.                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: A Personal Assistant                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is a beautiful shade represented by the hex code #46778F, which is a calming and soothing  │
# │  teal hue.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='Your favorite color is a beautiful shade represented by the hex code #46778F, which is a calming and soothing teal hue.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Handle this task: My favorite color is #46778F.', name=None, expected_output='A clear and concise answer to the question.', summary='Handle this task: My favorite color is #46778F....', raw='Your favorite color is a beautiful shade represented by the hex code #46778F, which is a calming and soothing teal hue.', pydantic=None, json_dict=None, agent='A Personal Assistant', output_format=<OutputFormat.RAW: 'raw'>)], token_usage=UsageMetrics(total_tokens=233, prompt_tokens=196, cached_prompt_tokens=0, completion_tokens=37, successful_requests=1))

# %%
user_query = "What is my favorite color?"

crew.kickoff(inputs={"user_task": user_query})
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: A Personal Assistant                                                                                    │
# │                                                                                                                 │
# │  Task: Handle this task: What is my favorite color?                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: A Personal Assistant                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is a beautiful shade represented by the hex code #46778F, which is a calming and soothing  │
# │  teal hue.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='Your favorite color is a beautiful shade represented by the hex code #46778F, which is a calming and soothing teal hue.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Handle this task: What is my favorite color?', name=None, expected_output='A clear and concise answer to the question.', summary='Handle this task: What is my favorite color?...', raw='Your favorite color is a beautiful shade represented by the hex code #46778F, which is a calming and soothing teal hue.', pydantic=None, json_dict=None, agent='A Personal Assistant', output_format=<OutputFormat.RAW: 'raw'>)], token_usage=UsageMetrics(total_tokens=607, prompt_tokens=533, cached_prompt_tokens=0, completion_tokens=74, successful_requests=2))

# %% [markdown]
# ### Long Term Memory

# %%
from crewai import Crew, Agent, Task, Process
from crewai.memory import LongTermMemory
from crewai.memory.storage.ltm_sqlite_storage import LTMSQLiteStorage

# %%
shared_db = "./agent_memory.db"

storage = LTMSQLiteStorage(db_path=shared_db)

long_memory = LongTermMemory(storage=storage)

# %%
agent1 = Agent(role="First Personal Assistant",
              goal="""You are a personal assistant that handles
                      user's tasks.""",
              backstory="""You are a personal assistant that
                           can help the user with their tasks.""",
              verbose=True)

task1 = Task(description="Handle this task: {user_task}",
            expected_output="A clear and concise answer to the question.",
            agent=agent1)

crew1 = Crew(
    agents=[agent1],
    tasks=[task1], 
    process=Process.sequential,
    memory=True,
    long_term_memory=long_memory
)
crew1.kickoff(inputs={"user_task": "My favorite color is #46778F."})
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: First Personal Assistant                                                                                │
# │                                                                                                                 │
# │  Task: Handle this task: My favorite color is #46778F.                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: First Personal Assistant                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is a beautiful shade of teal, specifically identified by the hex code #46778F.             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='Your favorite color is a beautiful shade of teal, specifically identified by the hex code #46778F.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Handle this task: My favorite color is #46778F.', name=None, expected_output='A clear and concise answer to the question.', summary='Handle this task: My favorite color is #46778F....', raw='Your favorite color is a beautiful shade of teal, specifically identified by the hex code #46778F.', pydantic=None, json_dict=None, agent='First Personal Assistant', output_format=<OutputFormat.RAW: 'raw'>)], token_usage=UsageMetrics(total_tokens=371, prompt_tokens=339, cached_prompt_tokens=0, completion_tokens=32, successful_requests=1))

# %%
import sqlite3

conn = sqlite3.connect("agent_memory.db")
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

tables = cursor.fetchall()

print("Tables in the database:")
for table in tables:
    print(table[0])

cursor.execute("SELECT * FROM long_term_memories;")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# Tables in the database:
# long_term_memories
# sqlite_sequence
# (1, 'Handle this task: My favorite color is #46778F.', '{"suggestions": ["Ensure the actual output is direct and concise without unnecessary preamble.", "Consider re-evaluating the clarity of the answer to make sure it directly addresses the task.", "Avoid excessive commentary that does not contribute to answering the question."], "quality": 7.0, "agent": "First Personal Assistant", "expected_output": "A clear and concise answer to the question."}', '1761359322.3910358', 7.0)
# (2, 'Handle this task: My favorite color is #46778F.', '{"suggestions": ["Ensure the output is simpler and more direct, addressing the task in a straightforward manner.", "Avoid unnecessary elaboration unless specifically requested.", "Consider associating the color code directly with its name, but keep it brief."], "quality": 7.0, "agent": "First Personal Assistant", "expected_output": "A clear and concise answer to the question."}', '1761359739.848298', 7.0)

# %%
task2 = Task(description="Handle this task: {user_task}",
            expected_output="A clear and concise answer to the question.",
            agent=agent1)

crew2 = Crew(
    agents=[agent1], 
    tasks=[task2], 
    process=Process.sequential,
    memory=True,
    long_term_memory=long_memory
)

crew2.kickoff(inputs={"user_task": "What is my favorite color?"})
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: First Personal Assistant                                                                                │
# │                                                                                                                 │
# │  Task: Handle this task: What is my favorite color?                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: First Personal Assistant                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is a beautiful shade of teal, specifically identified by the hex code #46778F.             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='Your favorite color is a beautiful shade of teal, specifically identified by the hex code #46778F.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Handle this task: What is my favorite color?', name=None, expected_output='A clear and concise answer to the question.', summary='Handle this task: What is my favorite color?...', raw='Your favorite color is a beautiful shade of teal, specifically identified by the hex code #46778F.', pydantic=None, json_dict=None, agent='First Personal Assistant', output_format=<OutputFormat.RAW: 'raw'>)], token_usage=UsageMetrics(total_tokens=727, prompt_tokens=663, cached_prompt_tokens=0, completion_tokens=64, successful_requests=2))

# %% [markdown]
# ### Entity Memory

# %%
from crewai import Crew, Agent, Task, Process
from crewai.memory import EntityMemory
from crewai.memory.storage.rag_storage import RAGStorage

shared_db = "./agent1_entity_memory.db"

storage = RAGStorage(path=shared_db, type="short_term")

entity_memory = EntityMemory(storage=storage)

# %%
remembering_agent = Agent(role="Remembering Agent",
                          goal="""You are a assistant that can
                                  remember the user's information.""",
                          backstory="""You are a assistant that can remember
                                       the user's information.""",
                          verbose=True)
            
task = Task(description="Handle this task: {user_task}",
            expected_output="A clear and concise answer to the question.",
            agent=remembering_agent)

crew = Crew(
    agents=[remembering_agent], 
    tasks=[task], 
    process=Process.sequential,
    memory=True,
    entity_memory=entity_memory
)

crew.kickoff(inputs={"user_task": "My favorite color is #46778F."})
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Remembering Agent                                                                                       │
# │                                                                                                                 │
# │  Task: Handle this task: My favorite color is #46778F.                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Remembering Agent                                                                                       │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Your favorite color is #46778F.                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='Your favorite color is #46778F.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Handle this task: My favorite color is #46778F.', name=None, expected_output='A clear and concise answer to the question.', summary='Handle this task: My favorite color is #46778F....', raw='Your favorite color is #46778F.', pydantic=None, json_dict=None, agent='Remembering Agent', output_format=<OutputFormat.RAW: 'raw'>)], token_usage=UsageMetrics(total_tokens=369, prompt_tokens=349, cached_prompt_tokens=0, completion_tokens=20, successful_requests=1))

# %%
crew._entity_memory.search("What is my favorite color?")
# Out:
# [{'id': '31da6f7e-f29f-4bc2-b9db-c8d305aa7d46',
#   'metadata': {'relationships': '- is referenced in the task description\n- is the main focus of the expected output'},
#   'context': 'favorite color(color): The color that the individual considers their favorite, represented in hexadecimal format.',
#   'score': 0.768923282623291},
#  {'id': '89956492-a338-4a0b-b3ca-08d69673fe99',
#   'metadata': {'relationships': '- is associated with the individual'},
#   'context': 'favorite color(attribute): The preferred color of the individual as mentioned in the task.',
#   'score': 0.8682315349578857},
#  {'id': '32b954fd-399a-4e0b-8af7-21514d7c13dc',
#   'metadata': {'relationships': '- is the value of the favorite color'},
#   'context': '#46778F(color code): A hexadecimal color code representing a specific shade of teal.',
#   'score': 1.1764724254608154}]

# %% [markdown]
# ### Resetting memory

# %%
crew.reset_memories(command_type = 'all')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/memory/storage/rag_storage.py:149, in RAGStorage.reset(self)
#     148 self.app.reset()
# --> 149 shutil.rmtree(f"{db_storage_path()}/{self.type}")
#     150 self.app = None
#
# File ~/anaconda3/envs/py312/lib/python3.12/shutil.py:759, in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     758     while stack:
# --> 759         _rmtree_safe_fd(stack, onexc)
#     760 finally:
#     761     # Close any file descriptors still on the stack.
#
# File ~/anaconda3/envs/py312/lib/python3.12/shutil.py:703, in _rmtree_safe_fd(stack, onexc)
#     702 err.filename = path
# --> 703 onexc(func, path, err)
#
# File ~/anaconda3/envs/py312/lib/python3.12/shutil.py:669, in _rmtree_safe_fd(stack, onexc)
#     668 if orig_entry is None:
# --> 669     orig_st = os.lstat(name, dir_fd=dirfd)
#     670 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/arunkumar/Library/Application Support/Crew_Ai/short_term'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/memory/entity/entity_memory.py:151, in EntityMemory.reset(self)
#     150 try:
# --> 151     self.storage.reset()
#     152 except Exception as e:
#
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/memory/storage/rag_storage.py:157, in RAGStorage.reset(self)
#     156 else:
# --> 157     raise Exception(
#     158         f"An error occurred while resetting the {self.type} memory: {e}"
#     159     )
#
# Exception: An error occurred while resetting the short_term memory: [Errno 2] No such file or directory: '/Users/arunkumar/Library/Application Support/Crew_Ai/short_term'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/crew.py:1393, in Crew._reset_all_memories(self)
#    1392 reset_fn: Callable = cast(Callable, config.get("reset"))
# -> 1393 reset_fn(system)
#    1394 self._logger.log(
#    1395     "info",
#    1396     f"[Crew ({self.name if self.name else self.id})] {name} memory has been reset",
#    1397 )
#
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/crew.py:1440, in Crew._get_memory_systems.<locals>.default_reset(memory)
#    1439 def default_reset(memory):
# -> 1440     return memory.reset()
#
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/memory/entity/entity_memory.py:153, in EntityMemory.reset(self)
#     152 except Exception as e:
# --> 153     raise Exception(f"An error occurred while resetting the entity memory: {e}")
#
# Exception: An error occurred while resetting the entity memory: An error occurred while resetting the short_term memory: [Errno 2] No such file or directory: '/Users/arunkumar/Library/Application Support/Crew_Ai/short_term'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/crew.py:1375, in Crew.reset_memories(self, command_type)
#    1374 if command_type == "all":
# -> 1375     self._reset_all_memories()
#    1376 else:
#
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/crew.py:1399, in Crew._reset_all_memories(self)
#    1398 except Exception as e:
# -> 1399     raise RuntimeError(
#    1400         f"[Crew ({self.name if self.name else self.id})] Failed to reset {name} memory: {str(e)}"
#    1401     ) from e
#
# RuntimeError: [Crew (crew)] Failed to reset Entity memory: An error occurred while resetting the entity memory: An error occurred while resetting the short_term memory: [Errno 2] No such file or directory: '/Users/arunkumar/Library/Application Support/Crew_Ai/short_term'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 crew.reset_memories(command_type = 'all')
#
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/crew.py:1382, in Crew.reset_memories(self, command_type)
#    1380 error_msg = f"Failed to reset {command_type} memory: {str(e)}"
#    1381 self._logger.log("error", error_msg)
# -> 1382 raise RuntimeError(error_msg) from e
#
# RuntimeError: Failed to reset all memory: [Crew (crew)] Failed to reset Entity memory: An error occurred while resetting the entity memory: An error occurred while resetting the short_term memory: [Errno 2] No such file or directory: '/Users/arunkumar/Library/Application Support/Crew_Ai/short_term'

# %%
crew.reset_memories(command_type='short')

# %%
crew.reset_memories(command_type='long')

# %%
crew.reset_memories(command_type='entity')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/memory/storage/rag_storage.py:149, in RAGStorage.reset(self)
#     148 self.app.reset()
# --> 149 shutil.rmtree(f"{db_storage_path()}/{self.type}")
#     150 self.app = None
#
# File ~/anaconda3/envs/py312/lib/python3.12/shutil.py:759, in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     758     while stack:
# --> 759         _rmtree_safe_fd(stack, onexc)
#     760 finally:
#     761     # Close any file descriptors still on the stack.
#
# File ~/anaconda3/envs/py312/lib/python3.12/shutil.py:703, in _rmtree_safe_fd(stack, onexc)
#     702 err.filename = path
# --> 703 onexc(func, path, err)
#
# File ~/anaconda3/envs/py312/lib/python3.12/shutil.py:669, in _rmtree_safe_fd(stack, onexc)
#     668 if orig_entry is None:
# --> 669     orig_st = os.lstat(name, dir_fd=dirfd)
#     670 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/arunkumar/Library/Application Support/Crew_Ai/short_term'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/memory/entity/entity_memory.py:151, in EntityMemory.reset(self)
#     150 try:
# --> 151     self.storage.reset()
#     152 except Exception as e:
#
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/memory/storage/rag_storage.py:157, in RAGStorage.reset(self)
#     156 else:
# --> 157     raise Exception(
#     158         f"An error occurred while resetting the {self.type} memory: {e}"
#     159     )
#
# Exception: An error occurred while resetting the short_term memory: [Errno 2] No such file or directory: '/Users/arunkumar/Library/Application Support/Crew_Ai/short_term'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/crew.py:1422, in Crew._reset_specific_memory(self, memory_type)
#    1421 reset_fn: Callable = cast(Callable, config.get("reset"))
# -> 1422 reset_fn(system)
#    1423 self._logger.log(
#    1424     "info",
#    1425     f"[Crew ({self.name if self.name else self.id})] {name} memory has been reset",
#    1426 )
#
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/crew.py:1440, in Crew._get_memory_systems.<locals>.default_reset(memory)
#    1439 def default_reset(memory):
# -> 1440     return memory.reset()
#
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/memory/entity/entity_memory.py:153, in EntityMemory.reset(self)
#     152 except Exception as e:
# --> 153     raise Exception(f"An error occurred while resetting the entity memory: {e}")
#
# Exception: An error occurred while resetting the entity memory: An error occurred while resetting the short_term memory: [Errno 2] No such file or directory: '/Users/arunkumar/Library/Application Support/Crew_Ai/short_term'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/crew.py:1377, in Crew.reset_memories(self, command_type)
#    1376     else:
# -> 1377         self._reset_specific_memory(command_type)
#    1379 except Exception as e:
#
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/crew.py:1428, in Crew._reset_specific_memory(self, memory_type)
#    1427 except Exception as e:
# -> 1428     raise RuntimeError(
#    1429         f"[Crew ({self.name if self.name else self.id})] Failed to reset {name} memory: {str(e)}"
#    1430     ) from e
#
# RuntimeError: [Crew (crew)] Failed to reset Entity memory: An error occurred while resetting the entity memory: An error occurred while resetting the short_term memory: [Errno 2] No such file or directory: '/Users/arunkumar/Library/Application Support/Crew_Ai/short_term'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 crew.reset_memories(command_type='entity')
#
# File ~/anaconda3/envs/py312/lib/python3.12/site-packages/crewai/crew.py:1382, in Crew.reset_memories(self, command_type)
#    1380 error_msg = f"Failed to reset {command_type} memory: {str(e)}"
#    1381 self._logger.log("error", error_msg)
# -> 1382 raise RuntimeError(error_msg) from e
#
# RuntimeError: Failed to reset entity memory: [Crew (crew)] Failed to reset Entity memory: An error occurred while resetting the entity memory: An error occurred while resetting the short_term memory: [Errno 2] No such file or directory: '/Users/arunkumar/Library/Application Support/Crew_Ai/short_term'

# %%
from crewai.utilities.paths import db_storage_path
import os

# Get the base storage path
storage_path = db_storage_path()
print(f"CrewAI storage location: {storage_path}")

# List all CrewAI storage directories
if os.path.exists(storage_path):
    print("\nStored files and directories:")
    for item in os.listdir(storage_path):
        item_path = os.path.join(storage_path, item)
        if os.path.isdir(item_path):
            print(f"📁 {item}/")
            # Show ChromaDB collections
            if os.path.exists(item_path):
                for subitem in os.listdir(item_path):
                    print(f"   └── {subitem}")
        else:
            print(f"📄 {item}")
else:
    print("No CrewAI storage directory found yet.")
# Out:
# CrewAI storage location: /Users/arunkumar/Library/Application Support/Crew_Ai
#
# Stored files and directories:
# 📁 6b8da010-232d-405b-872a-1fdc6533ce42/
#    └── data_level0.bin
#    └── length.bin
#    └── link_lists.bin
#    └── header.bin
# 📄 chromadb-d3e486717082d830db3c35c6869a6fc8.lock
# 📄 long_term_memory_storage.db
# 📁 6e8ef8ce-2799-4220-8faa-f6bcbf08e5eb/
#    └── data_level0.bin
#    └── length.bin
#    └── link_lists.bin
#    └── header.bin
# 📄 chroma.sqlite3
# 📄 latest_kickoff_task_outputs.db
# 📁 entities/
#    └── First_Personal_Assistant
#    └── Personal_Assistant
#    └── A_Personal_Assistant
# 📄 .crewai_user.json

# %%
import os
from pathlib import Path

# Store in project directory
project_root = Path(__file__).parent
storage_dir = project_root / "crewai_storage"

os.environ["CREWAI_STORAGE_DIR"] = str(storage_dir)

# Now all storage will be in your project directory
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       2 from pathlib import Path
#       4 # Store in project directory
# ----> 5 project_root = Path(__file__).parent
#       6 storage_dir = project_root / "crewai_storage"
#       8 os.environ["CREWAI_STORAGE_DIR"] = str(storage_dir)
#
# NameError: name '__file__' is not defined
