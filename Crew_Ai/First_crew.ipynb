# %%
#pip install crewai

# %%
#pip show crewai

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI
from crewai import LLM
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
#os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
#Groq
llm_gr = LLM(
    model="groq/llama-3.2-90b-text-preview",
    temperature=0.7
)

#ollama
from litellm import completion

# Configure LiteLLM to use Ollama
llm_olla = completion(
    model="ollama/llama3.2:latest",
    api_base="http://localhost:11434"
)

# %%
# llm = LLM(
#     model="openai/GPT-4o-mini", # call model by provider/model_name
#     temperature=0.8,
#     max_tokens=150,
#     top_p=0.9,
#     frequency_penalty=0.1,
#     presence_penalty=0.1,
#     stop=["END"],
#     seed=42
# )

# %% [markdown]
# Crew ai

# %%
#call ATC (in areo words)
from crewai import Agent,Task,Crew
agent1=Agent(
    name="Researcher",
    description="An AI assistant for research and gathers information.",
    goal="Find relevant insights from sales data.", #just the final output looking for
    role="Researcher", #not importsnt in adding the goal it gives a identifier
    backstory="An Ai assistant  desinged for resesrch task.", #very important in adding the backstory identifier
    llm=llm_olla,
    verbose=True
)

# %% [markdown]
# Task Execution Flow
# Tasks can be executed in two ways:
# Sequential: Tasks are executed in the order they are defined
# Hierarchical: Tasks are assigned to agents based on their roles and expertise

# %%
#Task it can be multile     (Sequntial/ Hirechail)
research_task=Task(
    name="Research Sales Data",
    description="Analyze sales data to identify trends and insights.",
    agent=agent1,
    expected_output="Summary of latetst advancement in F1 racing", #what you want in the output
    )

# %%
crew = Crew(
    agents=[agent1],
    tasks=[research_task],
    #process=Process.sequential  # or Process.hierarchical
)
#crew.kickoff()

# %% [markdown]
# CrewOutput(raw="To begin with, I'll utilize my machine learning capabilities to analyze the sales data, identifying trends and patterns that can provide valuable insights. My primary goal is to extract relevant information from the data, using various techniques such as regression analysis, clustering, and decision trees.\n\nFirstly, I will employ time-series analysis to examine the fluctuations in sales over time, highlighting any seasonal or periodic trends that may be present. This will enable me to pinpoint specific periods of increased or decreased sales activity, allowing for informed decisions to be made about future marketing strategies.\n\nNext, I will apply data visualization techniques, such as scatter plots and bar charts, to visualize the relationship between various sales-related factors, such as product type, region, and promotional campaigns. This will facilitate a better understanding of how different variables impact sales performance.\n\nFurthermore, I will leverage natural language processing (NLP) capabilities to analyze customer feedback and sentiment analysis data, providing valuable insights into customer perceptions and preferences. By identifying areas where customers have expressed satisfaction or dissatisfaction with products or services, businesses can make targeted improvements to enhance overall customer experience.\n\nAdditionally, I will utilize machine learning algorithms to identify correlations between sales data and external factors such as weather patterns, economic indicators, or global events. This will enable me to predict potential fluctuations in sales activity based on these external factors, allowing for proactive adjustments to be made to mitigate any negative impacts.\n\nFinally, I will perform clustering analysis on customer segmentation data to group customers based on demographic characteristics, behavior patterns, and purchase history. This will provide valuable insights into customer preferences and purchasing habits, enabling targeted marketing campaigns that resonate with specific audience segments.\n\nThroughout this process, I will continually update my understanding of the sales data as new information becomes available, ensuring that my analysis remains accurate and relevant over time. By applying a range of advanced analytics techniques, I am confident that I can uncover valuable insights from the sales data that will inform informed business decisions and drive growth.", pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Analyze sales data to identify trends and insights.', name='Research Sales Data', expected_output='Summary of latetst advancement in AI', summary='Analyze sales data to identify trends and insights....', raw="To begin with, I'll utilize my machine learning capabilities to analyze the sales data, identifying trends and patterns that can provide valuable insights. My primary goal is to extract relevant information from the data, using various techniques such as regression analysis, clustering, and decision trees.\n\nFirstly, I will employ time-series analysis to examine the fluctuations in sales over time, highlighting any seasonal or periodic trends that may be present. This will enable me to pinpoint specific periods of increased or decreased sales activity, allowing for informed decisions to be made about future marketing strategies.\n\nNext, I will apply data visualization techniques, such as scatter plots and bar charts, to visualize the relationship between various sales-related factors, such as product type, region, and promotional campaigns. This will facilitate a better understanding of how different variables impact sales performance.\n\nFurthermore, I will leverage natural language processing (NLP) capabilities to analyze customer feedback and sentiment analysis data, providing valuable insights into customer perceptions and preferences. By identifying areas where customers have expressed satisfaction or dissatisfaction with products or services, businesses can make targeted improvements to enhance overall customer experience.\n\nAdditionally, I will utilize machine learning algorithms to identify correlations between sales data and external factors such as weather patterns, economic indicators, or global events. This will enable me to predict potential fluctuations in sales activity based on these external factors, allowing for proactive adjustments to be made to mitigate any negative impacts.\n\nFinally, I will perform clustering analysis on customer segmentation data to group customers based on demographic characteristics, behavior patterns, and purchase history. This will provide valuable insights into customer preferences and purchasing habits, enabling targeted marketing campaigns that resonate with specific audience segments.\n\nThroughout this process, I will continually update my understanding of the sales data as new information becomes available, ensuring that my analysis remains accurate and relevant over time. By applying a range of advanced analytics techniques, I am confident that I can uncover valuable insights from the sales data that will inform informed business decisions and drive growth.", pydantic=None, json_dict=None, agent='Researcher', output_format=<OutputFormat.RAW: 'raw'>)], token_usage=UsageMetrics(total_tokens=592, prompt_tokens=198, cached_prompt_tokens=0, completion_tokens=394, successful_requests=1))

# %% [markdown]
# MULTI AGENT

# %%
agent2=Agent(
    name='Writer',
    description='An AI assistant for writing and content creation.',
    goal='Create a summary of the research findings.',
    role='Writer',
    backstory='An AI assistant designed for writing tasks.',
    llm=llm_olla,
    verbose=True
)

agent3=Agent(
    name='Reviewer',
    description='An AI assistant for reviewing and editing content.',
    goal='Ensure the summary is clear and accurate.',
    role='Reviewer',
    backstory='An AI assistant designed for reviewing tasks.',
    llm=llm_olla,
    verbose=True
)

# %%
write_report=Task(
    name='Write Report',
    description='Write a report based on the research findings.',
    agent=agent2,
    expected_output='A well-written report summarizing the research findings.',
)

review_report=Task(
    name='Review Report',
    description='Review the report for clarity and accuracy.',
    agent=agent3,
    expected_output='A reviewed and edited report ready for publication.',
)

# %%
multi_agent_crew = Crew(
    agents=[agent1,agent2, agent3],
    tasks=[research_task,write_report, review_report],
    verbose=True,
    #process=Process.sequential  # or Process.hierarchical
)
multi_agent_crew.kickoff()
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: a87df070-66e7-443d-adaf-17b3a0a11134                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ...

# %%
#!pip install crewai crewai-tools opik --upgrade

# %%
import opik

opik.configure(use_local=False)
# Out:
# OPIK: Your Opik API key is available in your account settings, can be found at https://www.comet.com/api/my/settings/ for Opik cloud
# OPIK: The API key provided is not valid on https://www.comet.com/. Please try again.
# OPIK: Configuration saved to file: /Users/arunkumar/.opik.config
# OPIK: Configuration completed successfully. Traces will be logged to 'Default Project' by default. To change the destination project, see: https://www.comet.com/docs/opik/tracing/log_traces#configuring-the-project-name

# %%
from crewai import Agent, Crew, Task, Process


class YourCrewName:
    def agent_one(self) -> Agent:
        return Agent(
            role="Data Analyst",
            goal="Analyze data trends in the market",
            backstory="An experienced data analyst with a background in economics",
            verbose=True,
        )

    def agent_two(self) -> Agent:
        return Agent(
            role="Market Researcher",
            goal="Gather information on market dynamics",
            backstory="A diligent researcher with a keen eye for detail",
            verbose=True,
        )

    def task_one(self) -> Task:
        return Task(
            name="Collect Data Task",
            description="Collect recent market data and identify trends.",
            expected_output="A report summarizing key trends in the market.",
            agent=self.agent_one(),
        )

    def task_two(self) -> Task:
        return Task(
            name="Market Research Task",
            description="Research factors affecting market dynamics.",
            expected_output="An analysis of factors influencing the market.",
            agent=self.agent_two(),
        )

    def crew(self) -> Crew:
        return Crew(
            agents=[self.agent_one(), self.agent_two()],
            tasks=[self.task_one(), self.task_two()],
            process=Process.sequential,
            verbose=True,
        )

# %%
from opik.integrations.crewai import track_crewai

track_crewai(project_name="crewai-opik-integration")

my_crew = YourCrewName().crew()
result = my_crew.kickoff()

print(result)
# Out:
# OPIK: Started logging traces to the "crewai-opik-integration" project at https://www.comet.com/opik/api/v1/session/redirect/projects/?trace_id=0199b274-6ffa-700e-8ecc-6a815bafcb28&path=aHR0cHM6Ly93d3cuY29tZXQuY29tL29waWsvYXBpLw==.
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: ad81cb9f-eb88-49ac-b73d-dac49d525805                                                                       │
# │  Tool Args:                                                                                                     │
# ...
