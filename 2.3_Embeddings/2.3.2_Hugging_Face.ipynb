# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["HF_TOKEN"]=os.getenv("HF_TOKEN")

#print(os.environ["HF_TOKEN"])

# %%
from langchain_huggingface import HuggingFaceEmbeddings

#This is huge and taking time rather than sentence-transformers/all-mpnet-base-v2
#less dimensions in OPEN Source, explore Gemini 
model1=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2") #382

model = HuggingFaceEmbeddings(model_name="BAAI/bge-large-en-v1.5") #1024 is good compared to all but takes time


text="This is the Second Hugging Face Embedding"

embedd=model.embed_query(text)

print(len(embedd))
# Out:
# 1024
