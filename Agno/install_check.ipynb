# %%
from agno.agent import Agent
from agno.db.sqlite import SqliteDb
from agno.models.anthropic import Claude
from agno.os import AgentOS
from agno.tools.mcp import MCPTools

# %%
from agno.agent import Agent
from agno.models.openrouter import OpenRouter

agent = Agent(
    model=OpenRouter(id="gpt-5-mini"),
    markdown=True
)

# Print the response in the terminal
agent.print_response("Share a 2 sentence horror story.")
# Out:
# ▰▱▱▱▱▱▱ Thinking...
# ┏━ Message ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ Share a 2 sentence horror story.                                             ┃
# ┃                                                                              ┃
# ▰▰▱▱▱▱▱ Thinking...━━━━━━━━━━━━┛
# ┏━ Message ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ Share a 2 sentence horror story.                                             ┃
# ┃                                                                              ┃
# ▰▰▰▱▱▱▱ Thinking...━━━━━━━━━━━━┛
# ┏━ Message ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ...

# %%
from typing import Iterator
from agno.agent import Agent, RunOutput, RunOutputEvent, RunEvent
from agno.models.anthropic import Claude
from agno.tools.hackernews import HackerNewsTools
from agno.models.openrouter import OpenRouter
from agno.utils.pprint import pprint_run_response

agent = Agent(
    model=OpenRouter(id="gpt-5-mini"),
    tools=[HackerNewsTools()],
    instructions="Write a report on the topic. Output only the report.",
    markdown=True,
)

# Run agent and return the response as a variable
response: RunOutput = agent.run("Trending startups and products.")
# Print the response
print(response.content)

################ STREAM RESPONSE #################
stream: Iterator[RunOutputEvent] = agent.run("Trending products", stream=True)
for chunk in stream:
    if chunk.event == RunEvent.run_content:
        print(chunk.content)

# ################ STREAM AND PRETTY PRINT #################
stream: Iterator[RunOutputEvent] = agent.run("Trending products", stream=True)
pprint_run_response(stream, markdown=True)
# Out:
# # Report: Trending Startups and Products (Overview & Outlook)
#
# Date: 2025-10-25
# Scope: market trends, leading sectors, representative startups and products (notable through mid‑2024), drivers & risks, and actionable recommendations for founders, investors and corporates.
#
# ---
#
# ## Executive summary
#
# Since 2022–2024 the startup landscape has been dominated by rapid advances in artificial intelligence (especially generative and foundation-model-driven products), plus sustained momentum in climate tech, health/biotech, developer tools, fintech innovation, and robotics/automation. Product innovation has shifted from pure novelty to verticalization and AI-native workflows: generative models are being integrated into domain-specific SaaS, developer toolchains, creative and enterprise applications, and hardware-software systems.
#
# Key themes:
# - AI-first products and AI agents are the single largest driver of new startups and fundraising interest.
# ...

# %%
response: RunOutput = agent.run(input="Hi tell me about Python SDK , MSAL , I am confused on it")
# Print the response in markdown format
pprint_run_response(response, markdown=True)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
os.environ ["GOOGLE_API_KEY"] ="AIzaSyBQ_pZ37jQiQG1tFGiyfViNrWX0ZXjew5U"

# %%
import requests

# Your API key
GOOGLE_API_KEY = "AIzaSyBQ_pZ37jQiQG1tFGiyfViNrWX0ZXjew5U"

# Google Maps Geocoding API endpoint
endpoint = "https://maps.googleapis.com/maps/api/geocode/json"

# Query parameters
params = {
    "address": "Singapore",
    "key": GOOGLE_API_KEY
}

# Make the request
try:
    response = requests.get(endpoint, params=params)
    response.raise_for_status()  # Raise error for HTTP issues
    data = response.json()

    # Check the API response status
    if data.get("status") == "OK":
        for result in data.get("results", []):
            print("Formatted address:", result.get("formatted_address"))
            print("Location:", result.get("geometry", {}).get("location"))
    else:
        print("API error:", data.get("status"), "-", data.get("error_message"))

except requests.exceptions.RequestException as e:
    print("Request failed:", e)
# Out:
# API error: REQUEST_DENIED - The provided API key is invalid.
